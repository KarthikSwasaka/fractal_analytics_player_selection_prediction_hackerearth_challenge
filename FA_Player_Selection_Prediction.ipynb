# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/karthik_swasaka/Downloads/dataset 2/train.csv')

# %%
df.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
df.shape
# Out:
# (13994, 30)

# %%
df.isnull().sum()
# Out:
# player_id                      0
# name                           0
# age                            0
# gender                        19
# country                        0
# height                         0
# weight                       417
# ball_controlling_skills      413
# body_reflexes                  0
# body_balance                   0
# jumping_skills                24
# penalties_conversion_rate     30
# mental_strength               28
# goalkeeping_skills             0
# defending_skills               0
# passing_skills                 0
# dribbling_skills               0
# shot_accuracy                572
# body_strength_stamina          0
# max_running_speed              0
# strong_foot                  552
# behaviour_rating             703
# matches_played               666
# fitness_rating               695
# trophies_won                   0
# dedication_level               0
# coaching                     125
# years_of_experience          144
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13994 entries, 0 to 13993
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   player_id                  13994 non-null  object
#  1   name                       13994 non-null  object
#  2   age                        13994 non-null  int64
#  3   gender                     13975 non-null  object
#  4   country                    13994 non-null  object
#  5   height                     13994 non-null  object
#  6   weight                     13577 non-null  object
#  7   ball_controlling_skills    13581 non-null  float64
#  8   body_reflexes              13994 non-null  float64
#  9   body_balance               13994 non-null  float64
#  10  jumping_skills             13970 non-null  float64
#  11  penalties_conversion_rate  13964 non-null  float64
#  12  mental_strength            13966 non-null  float64
# ...

# %%
df['gender'].fillna(df['gender'].mode()[0], inplace=True)
df['strong_foot'].fillna(df['strong_foot'].mode()[0], inplace=True)
df['coaching'].fillna(df['coaching'].mode()[0], inplace=True)

# %%
df['weight'] = pd.to_numeric(df['weight'].str.replace('lbs', ''), errors='coerce')

# %%
df['weight'].fillna(df['weight'].mean(), inplace=True)
df['ball_controlling_skills'].fillna(df['ball_controlling_skills'].mean(), inplace=True)
df['jumping_skills'].fillna(df['jumping_skills'].mean(), inplace=True)
df['penalties_conversion_rate'].fillna(df['penalties_conversion_rate'].mean(), inplace=True)
df['mental_strength'].fillna(df['mental_strength'].mean(), inplace=True)
df['shot_accuracy'].fillna(df['shot_accuracy'].mean(), inplace=True)
df['behaviour_rating'].fillna(df['behaviour_rating'].mean(), inplace=True)
df['matches_played'].fillna(df['matches_played'].mean(), inplace=True)
df['fitness_rating'].fillna(df['fitness_rating'].mean(), inplace=True)
df['years_of_experience'].fillna(df['years_of_experience'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# player_id                    0
# name                         0
# age                          0
# gender                       0
# country                      0
# height                       0
# weight                       0
# ball_controlling_skills      0
# body_reflexes                0
# body_balance                 0
# jumping_skills               0
# penalties_conversion_rate    0
# mental_strength              0
# goalkeeping_skills           0
# defending_skills             0
# passing_skills               0
# dribbling_skills             0
# shot_accuracy                0
# body_strength_stamina        0
# max_running_speed            0
# strong_foot                  0
# behaviour_rating             0
# matches_played               0
# fitness_rating               0
# trophies_won                 0
# dedication_level             0
# coaching                     0
# years_of_experience          0
# no_of_disqualifications      0
# selection                    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13994 entries, 0 to 13993
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   player_id                  13994 non-null  object
#  1   name                       13994 non-null  object
#  2   age                        13994 non-null  int64
#  3   gender                     13994 non-null  object
#  4   country                    13994 non-null  object
#  5   height                     13994 non-null  object
#  6   weight                     13994 non-null  float64
#  7   ball_controlling_skills    13994 non-null  float64
#  8   body_reflexes              13994 non-null  float64
#  9   body_balance               13994 non-null  float64
#  10  jumping_skills             13994 non-null  float64
#  11  penalties_conversion_rate  13994 non-null  float64
#  12  mental_strength            13994 non-null  float64
# ...

# %%
df.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2   176.0
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10   148.0
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2   172.0
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11   165.0
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8   158.0
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
plt.boxplot(df['age'], vert=False)
plt.xlabel('age')
plt.title('Distribution of age')
plt.show()

# %%
feature_to_analyze = 'age'

# Create a scatter plot
plt.scatter(df.index, df[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
# 1. Identify and remove outliers
lower_bound = 5
upper_bound = 35

# 2. Handle outliers
# You can handle outliers in several ways, such as replacing them with a specific value or imputing them.

# Example: Replace outliers with the nearest bound
df['age'] = df['age'].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))

# %%
feature_to_analyze = 'age'

# Create a scatter plot
plt.scatter(df.index, df[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
df['gender'].value_counts()
# Out:
# M    7011
# F    6983
# Name: gender, dtype: int64

# %%
df['country'].value_counts()
# Out:
# England          1157
# Germany           838
# Spain             796
# France            734
# Argentina         691
#                  ...
# New Caledonia       1
# Afghanistan         1
# Chad                1
# Turkmenistan        1
# Oman                1
# Name: country, Length: 163, dtype: int64

# %%
df['height'].value_counts()
# Out:
# 6'0     2251
# 5'10    2124
# 5'9     1603
# 5'11    1583
# 6'2     1442
# 6'1     1389
# 5'8      903
# 6'3      691
# 5'7      664
# 6'4      549
# 5'6      328
# 6'5      183
# 5'5      124
# 6'6       64
# 5'4       22
# 6'7       18
# 5'3       16
# 6'11       7
# 6'8        7
# 12'1       4
# 7'1        3
# 11'0       3
# 9'5        2
# 6'9        2
# 10'2       2
# 5'2        2
# 99'0       2
# 89'1       2
# 8'3        2
# 1'5        1
# 4'5        1
# Name: height, dtype: int64

# %%
df.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2   176.0
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10   148.0
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2   172.0
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11   165.0
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8   158.0
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
feature_to_analyze = 'behaviour_rating'

# Create a scatter plot
plt.scatter(df.index, df[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
# 1. Identify and remove outliers
lower_bound = 130
upper_bound = 210

# 2. Handle outliers
# You can handle outliers in several ways, such as replacing them with a specific value or imputing them.

# Example: Replace outliers with the nearest bound
df['weight'] = df['weight'].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))

# %%
feature_to_analyze = 'no_of_disqualifications'

# Create a scatter plot
plt.scatter(df.index, df[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
# 1. Identify and remove outliers
lower_bound = 28
upper_bound = 90

# 2. Handle outliers
# You can handle outliers in several ways, such as replacing them with a specific value or imputing them.

# Example: Replace outliers with the nearest bound
df['jumping_skills'] = df['jumping_skills'].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))

# %%
df.columns
# Out:
# Index(['player_id', 'name', 'age', 'gender', 'country', 'height', 'weight',
#        'ball_controlling_skills', 'body_reflexes', 'body_balance',
#        'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
#        'goalkeeping_skills', 'defending_skills', 'passing_skills',
#        'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
#        'max_running_speed', 'strong_foot', 'behaviour_rating',
#        'matches_played', 'fitness_rating', 'trophies_won', 'dedication_level',
#        'coaching', 'years_of_experience', 'no_of_disqualifications',
#        'selection'],
#       dtype='object')

# %%
df['goalkeeping_skills'].value_counts()
# Out:
# 11.0    3123
# 10.0    3115
# 12.0    2052
# 9.0     1953
# 13.0     859
#         ...
# 24.0       1
# 34.0       1
# 83.0       1
# 46.0       1
# 23.0       1
# Name: goalkeeping_skills, Length: 65, dtype: int64

# %%
df['shot_accuracy'].value_counts()
# Out:
# 47.17814    572
# 53.00000    408
# 54.00000    404
# 50.00000    396
# 55.00000    388
#            ...
# 8.00000       3
# 82.00000      2
# 83.00000      1
# 86.00000      1
# 7.00000       1
# Name: shot_accuracy, Length: 80, dtype: int64

# %%
df['strong_foot'].value_counts()
# Out:
# Right    8911
# Left     2531
# None     1281
# Any      1271
# Name: strong_foot, dtype: int64

# %%
df['behaviour_rating'].value_counts()
# Out:
# 5.822068    703
# 5.900000    605
# 6.300000    600
# 5.700000    597
# 6.200000    590
#            ...
# 9.300000      2
# 2.200000      2
# 9.500000      1
# 9.800000      1
# 9.600000      1
# Name: behaviour_rating, Length: 65, dtype: int64

# %%
df['matches_played'].value_counts()
# Out:
# 0.000000      9184
# 1.000000      3089
# 3.908463       666
# 37.000000      223
# 39.000000      211
# 36.000000      211
# 38.000000      193
# 76.000000       49
# 75.000000       49
# 74.000000       43
# 73.000000       42
# 113.000000      12
# 110.000000      11
# 112.000000       5
# 111.000000       2
# 150.000000       1
# 149.000000       1
# 151.000000       1
# 148.000000       1
# Name: matches_played, dtype: int64

# %%
df['fitness_rating'].value_counts()
# Out:
# 6.405482     695
# 7.000000     498
# 6.700000     453
# 6.800000     432
# 7.100000     431
#             ...
# 9.800000       4
# 1.000000       2
# 10.000000      2
# 9.900000       1
# 1.100000       1
# Name: fitness_rating, Length: 86, dtype: int64

# %%
df['trophies_won'].value_counts()
# Out:
# 3.0    2956
# 2.0    2878
# 4.0    2712
# 5.0    2699
# 0.0     821
# 1.0     775
# 7.0     537
# 6.0     525
# 9.0      48
# 8.0      43
# Name: trophies_won, dtype: int64

# %%
df['dedication_level'].value_counts()
# Out:
# Medium    9704
# High      3557
# Low        733
# Name: dedication_level, dtype: int64

# %%
df['coaching'].value_counts()
# Out:
# Academy        9515
# Talent Hunt    1993
# Unknown        1360
# Source         1126
# Name: coaching, dtype: int64

# %%
df['no_of_disqualifications'].value_counts()
# Out:
#  0.0      12818
#  4.0        424
#  5.0        236
#  6.0        209
# -999.0       73
#  12.0        56
#  8.0         56
#  9.0         51
#  10.0        47
#  18.0         9
#  16.0         4
#  14.0         3
#  13.0         3
#  15.0         2
#  24.0         1
#  25.0         1
#  21.0         1
# Name: no_of_disqualifications, dtype: int64

# %%
df['selection'].value_counts()
# Out:
# 1    7802
# 0    6192
# Name: selection, dtype: int64

# %%
df.columns
# Out:
# Index(['player_id', 'name', 'age', 'gender', 'country', 'height', 'weight',
#        'ball_controlling_skills', 'body_reflexes', 'body_balance',
#        'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
#        'goalkeeping_skills', 'defending_skills', 'passing_skills',
#        'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
#        'max_running_speed', 'strong_foot', 'behaviour_rating',
#        'matches_played', 'fitness_rating', 'trophies_won', 'dedication_level',
#        'coaching', 'years_of_experience', 'no_of_disqualifications',
#        'selection'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13994 entries, 0 to 13993
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   player_id                  13994 non-null  object
#  1   name                       13994 non-null  object
#  2   age                        13994 non-null  int64
#  3   gender                     13994 non-null  object
#  4   country                    13994 non-null  object
#  5   height                     13994 non-null  object
#  6   weight                     13994 non-null  float64
#  7   ball_controlling_skills    13994 non-null  float64
#  8   body_reflexes              13994 non-null  float64
#  9   body_balance               13994 non-null  float64
#  10  jumping_skills             13994 non-null  float64
#  11  penalties_conversion_rate  13994 non-null  float64
#  12  mental_strength            13994 non-null  float64
# ...

# %%
# Map the count values back to the original DataFrame
df['gender'] = df['gender'].map(df['gender'].value_counts())
df['country'] = df['country'].map(df['country'].value_counts())
df['height'] = df['height'].map(df['height'].value_counts())
df['strong_foot'] = df['strong_foot'].map(df['strong_foot'].value_counts())
df['coaching'] = df['coaching'].map(df['coaching'].value_counts())

# %%
# Define a custom label encoding mapping
label_encoding_mapping_DL = {
    "High": 3, "Medium": 2, "Low": 1
}

# Perform label encoding using the custom mapping
df['dedication_level'] = df['dedication_level'].map(label_encoding_mapping_DL)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13994 entries, 0 to 13993
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   player_id                  13994 non-null  object
#  1   name                       13994 non-null  object
#  2   age                        13994 non-null  int64
#  3   gender                     13994 non-null  int64
#  4   country                    13994 non-null  int64
#  5   height                     13994 non-null  int64
#  6   weight                     13994 non-null  float64
#  7   ball_controlling_skills    13994 non-null  float64
#  8   body_reflexes              13994 non-null  float64
#  9   body_balance               13994 non-null  float64
#  10  jumping_skills             13994 non-null  float64
#  11  penalties_conversion_rate  13994 non-null  float64
#  12  mental_strength            13994 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# player_id                    0
# name                         0
# age                          0
# gender                       0
# country                      0
# height                       0
# weight                       0
# ball_controlling_skills      0
# body_reflexes                0
# body_balance                 0
# jumping_skills               0
# penalties_conversion_rate    0
# mental_strength              0
# goalkeeping_skills           0
# defending_skills             0
# passing_skills               0
# dribbling_skills             0
# shot_accuracy                0
# body_strength_stamina        0
# max_running_speed            0
# strong_foot                  0
# behaviour_rating             0
# matches_played               0
# fitness_rating               0
# trophies_won                 0
# dedication_level             0
# coaching                     0
# years_of_experience          0
# no_of_disqualifications      0
# selection                    0
# ...

# %%
test_df = pd.read_csv('/Users/karthik_swasaka/Downloads/dataset 2/test.csv')

# %%
test_df.head()
# Out:
#     player_id               name  age gender       country height  weight  \
# 0  PLID_14644           Ha Matta   16      F       Austria    6'1  163lbs
# 1   PLID_5934      Rex Weinstock   23      F  South Africa    5'9  170lbs
# 2   PLID_5074      Raisa Angeles   18      F   Netherlands   5'10  154lbs
# 3  PLID_17357    Jong Flewelling   24      F      China PR    6'0  168lbs
# 4  PLID_13993  Dian Westmoreland   20      F     Australia    6'0  163lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  \
# 0                     68.0           68.0          54.0  ...
# 1                     65.0           73.0          78.0  ...
# 2                     72.0           79.0          64.0  ...
# 3                     64.0           76.0          65.0  ...
# 4                     53.0           58.0          57.0  ...
#
#    max_running_speed  strong_foot  behaviour_rating  matches_played  \
# 0               25.6        Right               6.5             0.0
# ...

# %%
test_df['gender'].fillna(test_df['gender'].mode()[0], inplace=True)
test_df['strong_foot'].fillna(test_df['strong_foot'].mode()[0], inplace=True)
test_df['coaching'].fillna(test_df['coaching'].mode()[0], inplace=True)

# %%
test_df['weight'] = pd.to_numeric(test_df['weight'].str.replace('lbs', ''), errors='coerce')

# %%
test_df['weight'].fillna(test_df['weight'].mean(), inplace=True)
test_df['ball_controlling_skills'].fillna(test_df['ball_controlling_skills'].mean(), inplace=True)
test_df['jumping_skills'].fillna(test_df['jumping_skills'].mean(), inplace=True)
test_df['penalties_conversion_rate'].fillna(test_df['penalties_conversion_rate'].mean(), inplace=True)
test_df['mental_strength'].fillna(test_df['mental_strength'].mean(), inplace=True)
test_df['shot_accuracy'].fillna(test_df['shot_accuracy'].mean(), inplace=True)
test_df['behaviour_rating'].fillna(test_df['behaviour_rating'].mean(), inplace=True)
test_df['matches_played'].fillna(test_df['matches_played'].mean(), inplace=True)
test_df['fitness_rating'].fillna(test_df['fitness_rating'].mean(), inplace=True)
test_df['years_of_experience'].fillna(test_df['years_of_experience'].mean(), inplace=True)

# %%
lower_bound = 5
upper_bound = 35
test_df['age'] = test_df['age'].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))

# %%
# 1. Identify and remove outliers
lower_bound = 28
upper_bound = 90

# 2. Handle outliers
# You can handle outliers in several ways, such as replacing them with a specific value or imputing them.

# Example: Replace outliers with the nearest bound
test_df['jumping_skills'] = test_df['jumping_skills'].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))

# %%
# 1. Identify and remove outliers
lower_bound = 130
upper_bound = 210

# 2. Handle outliers
# You can handle outliers in several ways, such as replacing them with a specific value or imputing them.

# Example: Replace outliers with the nearest bound
test_df['weight'] = test_df['weight'].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))

# %%
# Map the count values back to the original DataFrame
test_df['gender'] = test_df['gender'].map(test_df['gender'].value_counts())
test_df['country'] = test_df['country'].map(test_df['country'].value_counts())
test_df['height'] = test_df['height'].map(test_df['height'].value_counts())
test_df['strong_foot'] = test_df['strong_foot'].map(test_df['strong_foot'].value_counts())
test_df['coaching'] = test_df['coaching'].map(test_df['coaching'].value_counts())

# %%
# Define a custom label encoding mapping
test_label_encoding_mapping_DL = {
    "High": 3, "Medium": 2, "Low": 1
}

# Perform label encoding using the custom mapping
test_df['dedication_level'] = test_df['dedication_level'].map(test_label_encoding_mapping_DL)

# %%
test_df.head()
# Out:
#     player_id               name  age  gender  country  height  weight  \
# 0  PLID_14644           Ha Matta   16    4624      128     955   163.0
# 1   PLID_5934      Rex Weinstock   23    4624       36    1065   170.0
# 2   PLID_5074      Raisa Angeles   18    4624      225    1341   154.0
# 3  PLID_17357    Jong Flewelling   24    4624      155    1496   168.0
# 4  PLID_13993  Dian Westmoreland   20    4624      112    1496   163.0
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  \
# 0                     68.0           68.0          54.0  ...
# 1                     65.0           73.0          78.0  ...
# 2                     72.0           79.0          64.0  ...
# 3                     64.0           76.0          65.0  ...
# 4                     53.0           58.0          57.0  ...
#
#    max_running_speed  strong_foot  behaviour_rating  matches_played  \
# 0               25.6         5984               6.5             0.0
# ...

# %%
df.head()
# Out:
#     player_id                 name  age  gender  country  height  weight  \
# 0   PLID_4964           Keva Horan   23    7011       45    1442   176.0
# 1  PLID_11234           Herma Tann   18    7011      187    2124   148.0
# 2  PLID_19127         Eilene Kizer   16    6983      796    1442   172.0
# 3  PLID_17467       Andrea Badgett   27    7011      406    1583   165.0
# 4   PLID_9661  Jeremiah Bumbalough   19    6983      691     903   158.0
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...         8911
# 1                     54.0           69.0          70.0  ...         1271
# 2                     34.0           43.0          45.0  ...         2531
# 3                     79.0           73.0          76.0  ...         8911
# 4                     47.0           61.0          74.0  ...         8911
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
test_df.isnull().sum()
# Out:
# player_id                    0
# name                         0
# age                          0
# gender                       0
# country                      0
# height                       0
# weight                       0
# ball_controlling_skills      0
# body_reflexes                0
# body_balance                 0
# jumping_skills               0
# penalties_conversion_rate    0
# mental_strength              0
# goalkeeping_skills           0
# defending_skills             0
# passing_skills               0
# dribbling_skills             0
# shot_accuracy                0
# body_strength_stamina        0
# max_running_speed            0
# strong_foot                  0
# behaviour_rating             0
# matches_played               0
# fitness_rating               0
# trophies_won                 0
# dedication_level             0
# coaching                     0
# years_of_experience          0
# no_of_disqualifications      0
# dtype: int64

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9330 entries, 0 to 9329
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   player_id                  9330 non-null   object
#  1   name                       9330 non-null   object
#  2   age                        9330 non-null   int64
#  3   gender                     9330 non-null   int64
#  4   country                    9330 non-null   int64
#  5   height                     9330 non-null   int64
#  6   weight                     9330 non-null   float64
#  7   ball_controlling_skills    9330 non-null   float64
#  8   body_reflexes              9330 non-null   float64
#  9   body_balance               9330 non-null   float64
#  10  jumping_skills             9330 non-null   float64
#  11  penalties_conversion_rate  9330 non-null   float64
#  12  mental_strength            9330 non-null   float64
# ...

# %%
df['selection'].value_counts()
# Out:
# 1    7802
# 0    6192
# Name: selection, dtype: int64

# %%
X = df.drop(columns=['player_id','name','selection'])
y = df['selection']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import classification_report,confusion_matrix
pred=classifier.predict(X_test)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[3556  775]
#  [ 698 4767]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83      4331
#            1       0.86      0.87      0.87      5465
#
#     accuracy                           0.85      9796
#    macro avg       0.85      0.85      0.85      9796
# weighted avg       0.85      0.85      0.85      9796

# %%
test_df.head()
# Out:
#     player_id               name  age  gender  country  height  weight  \
# 0  PLID_14644           Ha Matta   16    4624      128     955   163.0
# 1   PLID_5934      Rex Weinstock   23    4624       36    1065   170.0
# 2   PLID_5074      Raisa Angeles   18    4624      225    1341   154.0
# 3  PLID_17357    Jong Flewelling   24    4624      155    1496   168.0
# 4  PLID_13993  Dian Westmoreland   20    4624      112    1496   163.0
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  \
# 0                     68.0           68.0          54.0  ...
# 1                     65.0           73.0          78.0  ...
# 2                     72.0           79.0          64.0  ...
# 3                     64.0           76.0          65.0  ...
# 4                     53.0           58.0          57.0  ...
#
#    max_running_speed  strong_foot  behaviour_rating  matches_played  \
# 0               25.6         5984               6.5             0.0
# ...

# %%
prediction = classifier.predict(test_df.drop(columns=['player_id','name']))

# %%
# Create a DataFrame with 'ID' and 'Predictions' columns
output_df = pd.DataFrame({'player_id': test_df['player_id'], 'selection': prediction})

# Display the output DataFrame
output_df.head()
# Out:
#     player_id  selection
# 0  PLID_14644          1
# 1   PLID_5934          0
# 2   PLID_5074          1
# 3  PLID_17357          0
# 4  PLID_13993          0

# %%
# Save the output DataFrame to a CSV file
output_file = "Player_Selection.csv"
output_df.to_csv(output_file, index=False)

print(f"DataFrame saved to {output_file}")
# Out:
# DataFrame saved to Player_Selection.csv
